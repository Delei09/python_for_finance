# %% [markdown]
# <a href="https://colab.research.google.com/github/Delei09/python_for_finance/blob/develop/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q yfinance
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 KB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 29.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 8.1 MB/s eta 0:00:00

# %%
# Libs que precisam ser importadas
import pandas as pd
import numpy as np
from pandas_datareader import data
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import yfinance as yf

# %%
# Escolher sempre o start a data a partir que quer traer os dados e o ticktet que quer analisar
gol_df = yf.download("GOLL4.SA", start='2015-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Info dos graficos
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2026 entries, 2015-01-02 to 2023-02-24
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2026 non-null   float64
#  1   High       2026 non-null   float64
#  2   Low        2026 non-null   float64
#  3   Close      2026 non-null   float64
#  4   Adj Close  2026 non-null   float64
#  5   Volume     2026 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 110.8 KB

# %%
gol_df.head()
# Mostra os 5 primeiros dados do data frame
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99   901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85  1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21  2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55  1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27  1569500

# %%
gol_df.tail(3)
# Mostra os 3 ultimos
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2023-02-22  5.90  5.92  5.61   5.68       5.68   8285200
# 2023-02-23  5.70  5.82  5.52   5.57       5.57  14964700
# 2023-02-24  5.59  5.77  5.51   5.60       5.60  11306000

# %%
gol_df.describe()
# Analisar a media dos valores historicos
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2026.000000  2026.000000  2026.000000  2026.000000  2026.000000
# mean     15.198040    15.572280    14.801703    15.158653    15.158653
# std       9.316283     9.487378     9.137279     9.309535     9.309535
# min       1.160000     1.180000     1.130000     1.160000     1.160000
# 25%       7.822500     8.040000     7.630000     7.802500     7.802500
# 50%      13.790000    14.150000    13.400000    13.695000    13.695000
# 75%      21.000000    21.445001    20.450001    20.877500    20.877500
# max      43.669998    44.619999    41.310001    43.790001    43.790001
#
#              Volume
# count  2.026000e+03
# mean   5.736448e+06
# std    5.069650e+06
# min    0.000000e+00
# 25%    2.189175e+06
# 50%    4.251050e+06
# 75%    7.656600e+06
# max    4.368050e+07

# %%
# Filtrar uma ação de uma coluna especifica
gol_df[gol_df['Close'] >= 43.79]
# Out:
#              Open       High    Low      Close  Adj Close   Volume
# Date
# 2019-08-01  41.25  44.619999  41.25  43.790001  43.790001  6664200

# %%
# Filtrar dois campos para pesquisar valor de coluna especifico
gol_df[(gol_df['Close'] >= 1.15) & (gol_df['Close'] <= 1.16) ]
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2016-01-22   1.2  1.26  1.14   1.16       1.16  3830600

# %% [markdown]
# Base de dados com mais ações

# %%
acoes = ['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']
acoes_df = pd.DataFrame()
for acao in acoes:
  acoes_df[acao] =  yf.download(acao, start='2015-01-01')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#             GOLL4.SA  CVCB3.SA   WEGE3.SA  MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2015-01-02     14.99     15.20   5.923076  0.232812  11.910702   47.259998
# 2015-01-05     14.85     15.00   5.963461  0.237187  11.544731   46.320000
# 2015-01-06     15.21     14.80   5.875000  0.234062  10.822770   46.580002
# 2015-01-07     14.55     14.67   5.807692  0.241875  10.746248   48.150002
# 2015-01-08     14.27     14.15   5.905769  0.240000  10.995774   48.509998
# ...              ...       ...        ...       ...        ...         ...
# 2023-02-16      5.97      3.71  38.779999  3.810000  28.500000  106.500000
# 2023-02-17      5.93      3.68  39.619999  3.660000  28.740000  105.559998
# 2023-02-22      5.68      3.56  38.400002  3.520000  28.209999  103.599998
# 2023-02-23      5.57      3.47  39.240002  3.560000  28.750000  104.150002
# 2023-02-24      5.60      3.37  38.470001  3.610000  27.610001  102.110001
#
# [2026 rows x 6 columns]

# %%
# Renomear as colunas
acoes_df =  acoes_df.rename(columns={'GOLL4.SA': 'GOL', 'CVCB3.SA': 'CVC', 'WEGE3.SA': 'WEGE', 'MGLU3.SA': 'MGLU', 'TOTS3.SA': 'TOTS', 'BOVA11.SA': 'BOVA'})
acoes_df.head()
# Out:
#               GOL    CVC      WEGE      MGLU       TOTS       BOVA
# Date
# 2015-01-02  14.99  15.20  5.923076  0.232812  11.910702  47.259998
# 2015-01-05  14.85  15.00  5.963461  0.237187  11.544731  46.320000
# 2015-01-06  15.21  14.80  5.875000  0.234062  10.822770  46.580002
# 2015-01-07  14.55  14.67  5.807692  0.241875  10.746248  48.150002
# 2015-01-08  14.27  14.15  5.905769  0.240000  10.995774  48.509998

# %%
acoes_df.isnull() # Para se existe valores nulos na tabela
# Out:
#               GOL    CVC   WEGE   MGLU   TOTS   BOVA
# Date
# 2015-01-02  False  False  False  False  False  False
# 2015-01-05  False  False  False  False  False  False
# 2015-01-06  False  False  False  False  False  False
# 2015-01-07  False  False  False  False  False  False
# 2015-01-08  False  False  False  False  False  False
# ...           ...    ...    ...    ...    ...    ...
# 2023-02-16  False  False  False  False  False  False
# 2023-02-17  False  False  False  False  False  False
# 2023-02-22  False  False  False  False  False  False
# 2023-02-23  False  False  False  False  False  False
# 2023-02-24  False  False  False  False  False  False
#
# [2026 rows x 6 columns]

# %%
acoes_df.shape # Mostra quantas linha e quantas colunas tem
# Out:
# (2026, 6)

# %%
acoes_df.dropna(inplace=True) # Apaga os valores nulos

# %%
acoes_df.isnull().sum() # Analisar se alguma ação tem dados nulos
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.columns # Traz todas as colunas
# Out:
# Index(['GOL', 'CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
acoes_df.describe()
# Out:
#                GOL          CVC         WEGE         MGLU         TOTS  \
# count  2026.000000  2026.000000  2026.000000  2026.000000  2026.000000
# mean     15.158653    27.594627    17.342967     6.699650    18.096476
# std       9.309535    16.410366    12.687322     7.574404     9.424636
# min       1.160000     3.370000     4.942307     0.030585     7.156402
# 25%       7.802500    14.700000     6.777885     0.416649    10.084173
# 50%      13.695000    21.610001     9.415000     3.890781    12.640982
# 75%      20.877500    42.515000    30.998750     9.725000    27.527500
# max      43.790001    64.800003    46.105000    27.450001    40.599998
#
#               BOVA
# count  2026.000000
# mean     82.298446
# std      23.963365
# min      36.450001
# 25%      60.455001
# 50%      83.410000
# 75%     103.680000
# max     125.750000

# %%
sns.histplot(acoes_df['GOL']);

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.histplot(acoes_df[acoes_df.columns[i]]);
  plt.title(acoes_df.columns[i])

# %%
acoes_df[acoes_df.columns[1]]
# Out:
# Date
# 2015-01-02    15.20
# 2015-01-05    15.00
# 2015-01-06    14.80
# 2015-01-07    14.67
# 2015-01-08    14.15
#               ...
# 2023-02-16     3.71
# 2023-02-17     3.68
# 2023-02-22     3.56
# 2023-02-23     3.47
# 2023-02-24     3.37
# Name: CVC, Length: 2026, dtype: float64

# %%
sns.boxplot(x = acoes_df['GOL'])
# Out:
# <AxesSubplot:xlabel='GOL'>

# %%
plt.figure(figsize=(10,50))
i = 1
for i in np.arange(1, len(acoes_df.columns)):
  plt.subplot(7, 1, i + 1)
  sns.boxplot(x = acoes_df[acoes_df.columns[i]]);
  plt.title(acoes_df.columns[i])

# %%
acoes_df = acoes_df.reset_index()
acoes_df.plot(x="Date",figsize=(15,7), title="Histórico")
# Out:
# <AxesSubplot:title={'center':'Histórico'}, xlabel='Date'>

# %%
acoes_df
# Out:
#            Date    GOL    CVC       WEGE      MGLU       TOTS        BOVA
# 0    2015-01-02  14.99  15.20   5.923076  0.232812  11.910702   47.259998
# 1    2015-01-05  14.85  15.00   5.963461  0.237187  11.544731   46.320000
# 2    2015-01-06  15.21  14.80   5.875000  0.234062  10.822770   46.580002
# 3    2015-01-07  14.55  14.67   5.807692  0.241875  10.746248   48.150002
# 4    2015-01-08  14.27  14.15   5.905769  0.240000  10.995774   48.509998
# ...         ...    ...    ...        ...       ...        ...         ...
# 2021 2023-02-16   5.97   3.71  38.779999  3.810000  28.500000  106.500000
# 2022 2023-02-17   5.93   3.68  39.619999  3.660000  28.740000  105.559998
# 2023 2023-02-22   5.68   3.56  38.400002  3.520000  28.209999  103.599998
# 2024 2023-02-23   5.57   3.47  39.240002  3.560000  28.750000  104.150002
# 2025 2023-02-24   5.60   3.37  38.470001  3.610000  27.610001  102.110001
#
# [2026 rows x 7 columns]

# %%
# CALCULAR O CRESCIMENTO PROPORCIONAL
acoes_df_normalizado = acoes_df.copy()
acoes_df_normalizado.set_index('Date')
for i in acoes_df_normalizado.columns[1:]:
  acoes_df_normalizado[i] = acoes_df_normalizado[i] / acoes_df_normalizado[i][0]

acoes_df_normalizado
# Out:
#            Date       GOL       CVC      WEGE       MGLU      TOTS      BOVA
# 0    2015-01-02  1.000000  1.000000  1.000000   1.000000  1.000000  1.000000
# 1    2015-01-05  0.990660  0.986842  1.006818   1.018792  0.969274  0.980110
# 2    2015-01-06  1.014676  0.973684  0.991883   1.005369  0.908659  0.985612
# 3    2015-01-07  0.970647  0.965132  0.980520   1.038928  0.902235  1.018832
# 4    2015-01-08  0.951968  0.930921  0.997078   1.030875  0.923184  1.026449
# ...         ...       ...       ...       ...        ...       ...       ...
# 2021 2023-02-16  0.398266  0.244079  6.547273  16.365135  2.392806  2.253491
# 2022 2023-02-17  0.395597  0.242105  6.689092  15.720839  2.412956  2.233601
# 2023 2023-02-22  0.378919  0.234211  6.483118  15.119495  2.368458  2.192129
# 2024 2023-02-23  0.371581  0.228289  6.624936  15.291308  2.413796  2.203767
# 2025 2023-02-24  0.373582  0.221711  6.494936  15.506073  2.318083  2.160601
#
# [2026 rows x 7 columns]

# %%
acoes_df_normalizado.plot(x="Date",figsize=(15,7), title="Histórico")
# Out:
# <AxesSubplot:title={'center':'Histórico'}, xlabel='Date'>

# %%
figura = px.line(title='Historico')
for i in acoes_df.columns[1:]:
  figura.add_scatter(x=acoes_df['Date'],y=acoes_df[i], name=i)

figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
figura = px.line(title='Historico normalizado')
for i in acoes_df_normalizado.columns[1:]:
  figura.add_scatter(x=acoes_df_normalizado['Date'],y=acoes_df_normalizado[i], name=i)

figura.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# SEÇÃO 4 => TAXA DE RETORNO DE AÇÕES
#
# taxa_retorno = (preco_final - preco_inicial / preco_inicial) * 100
#
# taxa_retorno_dividendo = ( (preco_final + dividendo) - preco_inicial / preco_inicial) * 100

# %%
acoes_df['GOL']
# Out:
# 0       14.99
# 1       14.85
# 2       15.21
# 3       14.55
# 4       14.27
#         ...
# 2021     5.97
# 2022     5.93
# 2023     5.68
# 2024     5.57
# 2025     5.60
# Name: GOL, Length: 2026, dtype: float64

# %%
acoes_df['GOL'][len(acoes_df) - 1]
acoes_df['GOL'][0]

()
# Out:
# 5.599999904632568

# %%
( (acoes_df['GOL'][len(acoes_df) - 1] - acoes_df['GOL'][0]) / acoes_df['GOL'][0]) * 100
# Out:
# -62.64176123990133

# %%
( (acoes_df['CVC'][len(acoes_df) - 1] - acoes_df['CVC'][0]) / acoes_df['CVC'][0]) * 100
# Out:
# -77.82894784311179

# %%
( (acoes_df['WEGE'][len(acoes_df) - 1] - acoes_df['WEGE'][0]) / acoes_df['WEGE'][0]) * 100
# Out:
# 549.4936115671495

# %%
( (acoes_df['BOVA'][len(acoes_df) - 1] - acoes_df['BOVA'][0]) / acoes_df['BOVA'][0]) * 100
# Out:
# 116.06010206696706
